# %% [markdown]
# # Running 'ellipse' with sigma-clipping:

# %% [markdown]
# In this example, we execute the basic fitting demonstrated in the 'example1.ipynb' notebook, with the main difference that the fit is performed with sigma-clipping.
#
# We start in the same way:

# %%
from astropy.io import fits
image = fits.open("../../test/data/M51.fits")
pixel_data = image[0].data

from isophote.ellipse import Ellipse
ell1 = Ellipse(pixel_data)
# Out:
# Centering on object....
# Done. Found x0 = 257.0, y0 = 258.0

# %% [markdown]
# Sigma-clipping is implemented via parameters on the 'fit_image' method. In this example, due to the significant contamination of the image by non-elliptical features, we apply quite aggressive clipping.

# %%
isophote_list = ell1.fit_image(sclip=2., nclip=3)
# Out:
# #
# # Semi-      Isophote         Ellipticity    Position     Grad.   Data  Flag Iter. Stop
# # major        mean                           Angle        rel.                    code
# # axis       intensity                                    error
# #(pixel)                                     (degree)
# #
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2d13d2ba689b> in <module>()
# ----> 1 isophote_list = ell1.fit_image(sclip=2., nclip=3)
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/ellipse.pyc in fit_image(self, sma0, minsma, maxsma, step, conver, minit, maxit, fflag, maxgerr, sclip, nclip, integrmode, linear, maxrit, verbose)
#     311                                          sclip, nclip, integrmode,
#     312                                          linear, maxrit, noniterate=noiter,
# --> 313                                          isophote_list=isophote_list)
#     314
#     315             # check for failed fit.
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/ellipse.pyc in fit_isophote(self, sma, step, conver, minit, maxit, fflag, maxgerr, sclip, nclip, integrmode, linear, maxrit, noniterate, going_inwards, isophote_list)
#     513             isophote = self._iterative(sma, step, linear, geometry, sclip, nclip,
#     514                                        integrmode, conver, minit, maxit, fflag,
# --> 515                                        maxgerr, going_inwards)
#     516
#     517         # store result in list
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/ellipse.pyc in _iterative(self, sma, step, linear, geometry, sclip, nclip, integrmode, conver, minit, maxit, fflag, maxgerr, going_inwards)
#     538             fitter = CentralFitter(sample)
#     539
# --> 540         isophote = fitter.fit(conver, minit, maxit, fflag, maxgerr, going_inwards)
#     541
#     542         return isophote
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/fitter.pyc in fit(self, conver, minit, maxit, fflag, maxgerr, going_inwards)
#     117
#     118             # Force the sample to compute its gradient and associated values.
# --> 119             sample.update()
#     120
#     121             # The extract() method returns sampled values as a 2-d numpy array
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/sample.pyc in update(self)
#     264
#     265         # Update the mean value first, using extraction from main sample.
# --> 266         s = self.extract()
#     267         self.mean = np.mean(s[2])
#     268
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/sample.pyc in extract(self)
#     137             return self.values
#     138         else:
# --> 139             s = self._extract()
#     140             self.values = s
#     141             return s
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/sample.pyc in _extract(self)
#     213
#     214         # apply sigma-clipping.
# --> 215         angles, radii, intensities = self._sigma_clip(angles, radii, intensities)
#     216
#     217         # actual number of sampled points, after sigma-clip removed outliers.
#
# /Users/song/Dropbox/work/project/isophote/isophote/ellipse/sample.pyc in _sigma_clip(self, angles, radii, intensities)
#     227
#     228             for iter in range(self.nclip):
# --> 229                 angles, radii, intensities = self._iter_sigma_clip(angles.copy(), radii.copy(), intensities.copy())
#     230
#     231         return np.array(angles), np.array(radii), np.array(intensities)
#
# AttributeError: 'list' object has no attribute 'copy'

# %% [markdown]
# Note how the added stability provided by sigma-clipping allows the fit to proceed further outwards before sensing a too low signal-to-noise condition.

# %% [markdown]
# ## Plotting results

# %% [markdown]
# Similar to what we did before in notebook 'example1.ipynb':

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['image.origin'] = 'lower'

# %%
plt.figure(figsize=(8, 4))

plt.scatter(isophote_list.sma**0.25, -2.5*np.log10(isophote_list.intens))

plt.xlabel('sma**1/4')
plt.ylabel('Magnitude')
plt.gca().invert_yaxis()
plt.title("M51 profile with sigma-clip")

# %%
plt.figure(figsize=(10, 5))
plt.figure(1)

plt.subplot(221)
plt.errorbar(isophote_list.sma, isophote_list.eps, yerr=isophote_list.ellip_err, fmt='o', markersize=4)
plt.title('EPS')

plt.subplot(222)
plt.errorbar(isophote_list.sma, isophote_list.pa/np.pi*180., yerr=isophote_list.pa_err/np.pi* 80., fmt='o', markersize=4)
plt.title('PA (deg.)')

plt.subplot(223)
plt.errorbar(isophote_list.sma, isophote_list.x0, yerr=isophote_list.x0_err, fmt='o', markersize=4)
plt.title('X0')

plt.subplot(224)
plt.errorbar(isophote_list.sma, isophote_list.y0, yerr=isophote_list.y0_err, fmt='o', markersize=4)
plt.title('Y0')

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.35, wspace=0.35)

# %% [markdown]
# Overplot a few "isophotes" on the image display:

# %%
import matplotlib.cm as cm

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(pixel_data, cmap=cm.gnuplot, vmin=0, vmax=1000)
plt.axis([0,511,0,511])

iso1 = isophote_list.get_closest(20.)
iso2 = isophote_list.get_closest(50.)
iso3 = isophote_list.get_closest(90.)

x, y, = iso1.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso2.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso3.sampled_coordinates()
plt.plot(x, y, color='white')

# %% [markdown]
# Brightness samples associated with the three isophotes above are plotted next.
#
# Note that the angles in the raw sample arrays are defined w.r.t the semi-major axis position angle. To plot everything in the same coordinate system, we have to offset each isophote's angles array by the corresponding position angle.

# %%
plt.figure(figsize=(10, 3))

plt.scatter((iso1.sample.values[0]+iso1.sample.geometry.pa)/np.pi*180., iso1.sample.values[2], color='red')
plt.scatter((iso2.sample.values[0]+iso2.sample.geometry.pa)/np.pi*180., iso2.sample.values[2], color='black')
plt.scatter((iso3.sample.values[0]+iso3.sample.geometry.pa)/np.pi*180., iso3.sample.values[2], color='blue')

plt.ylabel("Intensity")
plt.xlabel("Angle (deg.)")

# %% [markdown]
# Parameters that measure deviations from a perfect ellipse can be plotted like this:

# %%
plt.figure(figsize=(10, 5))
plt.figure(1)
limits = [0., 100., -0.1, 0.1]

plt.subplot(221)
plt.axis(limits)
plt.errorbar(isophote_list.sma, isophote_list.a3, yerr=isophote_list.a3_err, fmt='o', markersize=4)
plt.title('A3')

plt.subplot(222)
plt.axis(limits)
plt.errorbar(isophote_list.sma, isophote_list.b3, yerr=isophote_list.b3_err, fmt='o', markersize=4)
plt.title('B3')

plt.subplot(223)
plt.axis(limits)
plt.errorbar(isophote_list.sma, isophote_list.a4, yerr=isophote_list.a4_err, fmt='o', markersize=4)
plt.title('A4')

plt.subplot(224)
plt.axis(limits)
plt.errorbar(isophote_list.sma, isophote_list.b4, fmt='o', yerr=isophote_list.b4_err, markersize=4)
plt.title('B4')

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.35, wspace=0.35)
